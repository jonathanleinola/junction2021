# %%
import plotly as px
import pandas as pd

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\llmkh\anaconda3\lib\site-packages (5.4.0)
# Requirement already satisfied: six in c:\users\llmkh\anaconda3\lib\site-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\llmkh\anaconda3\lib\site-packages (from plotly) (8.0.1)

# %%
df3 = pd.read_csv("spend_data.csv")
df3
# Out:
#        SourceRowId   Date      DocumentId  DocumentLineId  ProductId  \
# 0            69041  44019  DOC235E1967D43               2        NaN
# 1            69042  44022  DOC2E92F738F42               2        NaN
# 2            69043  44023  DOC2CD16DF9B16               2        NaN
# 3            69044  44015  DOC25014385EC6               2        NaN
# 4            69045  44015  DOC2EE4B883E50               2        NaN
# ...            ...    ...             ...             ...        ...
# 13803        82844  44016  DOC2220D161149               2        NaN
# 13804        82845  44018  DOC2EAA9A28767               2        NaN
# 13805        82846  44018  DOC200BC612928               2        NaN
# 13806        82847  44019  DOC2C0C030603B               2        NaN
# 13807        82848  44019  DOC2D7E340B54A               2        NaN
#
#       ProductName  SpendOriginalCurrency OriginalCurrency      SpendEUR  \
# 0             NaN           14445.796860              EUR  14445.796860
# 1             NaN           42631.120576              EUR  42631.120576
# 2             NaN           42631.120576              EUR  42631.120576
# 3             NaN           14445.796860              EUR  14445.796860
# 4             NaN             419.123700              EUR    419.123700
# ...           ...                    ...              ...           ...
# 13803         NaN             753.984912              EUR    753.984912
# 13804         NaN             362.016562              EUR    362.016562
# 13805         NaN            7336.458091              EUR   7336.458091
# 13806         NaN             362.016562              EUR    362.016562
# 13807         NaN            7336.458091              EUR   7336.458091
#
#        Quantity  UOM  VendorId               VendorName VendorCity  \
# 0           NaN  NaN        35         AC NIELSEN GmbH.       WIEN
# 1           NaN  NaN        35         AC NIELSEN GmbH.       WIEN
# 2           NaN  NaN        35         AC NIELSEN GmbH.       WIEN
# 3           NaN  NaN        35         AC NIELSEN GmbH.       WIEN
# 4           NaN  NaN        35         AC NIELSEN GmbH.       WIEN
# ...         ...  ...       ...                      ...        ...
# 13803       NaN  NaN        45  Dachser - Austria GmbH.    Himberg
# 13804       NaN  NaN        45  Dachser - Austria GmbH.    Himberg
# 13805       NaN  NaN        45  Dachser - Austria GmbH.    Himberg
# 13806       NaN  NaN        45  Dachser - Austria GmbH.    Himberg
# 13807       NaN  NaN        45  Dachser - Austria GmbH.    Himberg
#
#       VendorCountry CategoryL1             CategoryL2
# 0                AT   Indirect  Professional Services
# 1                AT   Indirect  Professional Services
# 2                AT   Indirect  Professional Services
# 3                AT   Indirect  Professional Services
# 4                AT   Indirect  Professional Services
# ...             ...        ...                    ...
# 13803            AT   Indirect                  Fleet
# 13804            AT   Indirect                  Fleet
# 13805            AT   Indirect                  Fleet
# 13806            AT   Indirect                  Fleet
# 13807            AT   Indirect                  Fleet
#
# [13808 rows x 17 columns]

# %%
from pycountry_convert import country_alpha2_to_country_name, country_name_to_country_alpha3

df3.VendorCountry.value_counts()
df3['VendorCountry'] = df3.VendorCountry.apply(lambda x: country_name_to_country_alpha3(country_alpha2_to_country_name(x)))

df3
# Out:
#        SourceRowId   Date      DocumentId  DocumentLineId  ProductId  \
# 0            69041  44019  DOC235E1967D43               2        NaN
# 1            69042  44022  DOC2E92F738F42               2        NaN
# 2            69043  44023  DOC2CD16DF9B16               2        NaN
# 3            69044  44015  DOC25014385EC6               2        NaN
# 4            69045  44015  DOC2EE4B883E50               2        NaN
# ...            ...    ...             ...             ...        ...
# 13803        82844  44016  DOC2220D161149               2        NaN
# 13804        82845  44018  DOC2EAA9A28767               2        NaN
# 13805        82846  44018  DOC200BC612928               2        NaN
# 13806        82847  44019  DOC2C0C030603B               2        NaN
# 13807        82848  44019  DOC2D7E340B54A               2        NaN
#
#       ProductName  SpendOriginalCurrency OriginalCurrency      SpendEUR  \
# 0             NaN           14445.796860              EUR  14445.796860
# 1             NaN           42631.120576              EUR  42631.120576
# 2             NaN           42631.120576              EUR  42631.120576
# 3             NaN           14445.796860              EUR  14445.796860
# 4             NaN             419.123700              EUR    419.123700
# ...           ...                    ...              ...           ...
# 13803         NaN             753.984912              EUR    753.984912
# 13804         NaN             362.016562              EUR    362.016562
# 13805         NaN            7336.458091              EUR   7336.458091
# 13806         NaN             362.016562              EUR    362.016562
# 13807         NaN            7336.458091              EUR   7336.458091
#
#        Quantity  UOM  VendorId               VendorName VendorCity  \
# 0           NaN  NaN        35         AC NIELSEN GmbH.       WIEN
# 1           NaN  NaN        35         AC NIELSEN GmbH.       WIEN
# 2           NaN  NaN        35         AC NIELSEN GmbH.       WIEN
# 3           NaN  NaN        35         AC NIELSEN GmbH.       WIEN
# 4           NaN  NaN        35         AC NIELSEN GmbH.       WIEN
# ...         ...  ...       ...                      ...        ...
# 13803       NaN  NaN        45  Dachser - Austria GmbH.    Himberg
# 13804       NaN  NaN        45  Dachser - Austria GmbH.    Himberg
# 13805       NaN  NaN        45  Dachser - Austria GmbH.    Himberg
# 13806       NaN  NaN        45  Dachser - Austria GmbH.    Himberg
# 13807       NaN  NaN        45  Dachser - Austria GmbH.    Himberg
#
#       VendorCountry CategoryL1             CategoryL2
# 0               AUT   Indirect  Professional Services
# 1               AUT   Indirect  Professional Services
# 2               AUT   Indirect  Professional Services
# 3               AUT   Indirect  Professional Services
# 4               AUT   Indirect  Professional Services
# ...             ...        ...                    ...
# 13803           AUT   Indirect                  Fleet
# 13804           AUT   Indirect                  Fleet
# 13805           AUT   Indirect                  Fleet
# 13806           AUT   Indirect                  Fleet
# 13807           AUT   Indirect                  Fleet
#
# [13808 rows x 17 columns]

# %%
df3 = df3[df3["SpendEUR"] >= 0]
df3["SpendEUR"] = df3["SpendEUR"].astype(int)
df3["SpendEUR"]
# Out:
# <ipython-input-55-49f7c63a21fb>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0        14445
# 1        42631
# 2        42631
# 3        14445
# 4          419
#          ...
# 13803      753
# 13804      362
# 13805     7336
# 13806      362
# 13807     7336
# Name: SpendEUR, Length: 13493, dtype: int32

# %%
import plotly.express as px

#df = px.data.gapminder()
fig = px.scatter_geo(df3, locations="VendorCountry", color ="VendorCountry",
                     hover_name="CategoryL2", size="SpendEUR",
                     projection="natural earth")
fig.show()
# Out:
# <div>                            <div id="16ea415b-072b-4324-9865-36a648dc132c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16ea415b-072b-4324-9865-36a648dc132c")) {                    Plotly.newPlot(                        "16ea415b-072b-4324-9865-36a648dc132c",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>VendorCountry=%{location}<br>SpendEUR=%{marker.size}<extra></extra>","hovertext":["Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Professional Services","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Flour & Grain","Flour & Grain","Plastic","Plastic","Plastic","Flour & Grain","Flour & Grain","Flour & Grain","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Plastic","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Utilities","Flour & Grain","Plastic","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flour & Grain","Flou ...
